# %% [markdown]
# # Kiểu dữ liệu

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
a = "Hello"
b = "Python"
c = a + " "+ b
print(c)
# Out:
# Hello Python

# %%
# True -> 1, False -> 0
a = False
b = False
c = a + b
print(c)
# Out:
# 0

# %%
a = 10
b = True
c = a + b
print(c)
# Out:
# 11

# %% [markdown]
# # Toán tử

# %% [markdown]
# ## Toán tử cộng

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## Toán tử trừ

# %%
5-2
# Out:
# 3

# %% [markdown]
# ## Toán tử nhân

# %%
6*2
# Out:
# 12

# %% [markdown]
# ## Toán tử chia

# %%
6/2
# Out:
# 3.0

# %% [markdown]
# ## Chia lấy dư

# %%
9%4
# Out:
# 1

# %% [markdown]
# ## Lũy thừa

# %%
2**2
# Out:
# 4

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
y = 4
z = 9

# %%
x > y
# Out:
# True

# %%
x + y >= z
# Out:
# True

# %%
x ** 2 <= z
# Out:
# False

# %%
(x ** 2 - z) **0.5 == y
# Out:
# True

# %%
x + y + (x < y) -1 <= z
# Out:
# True

# %%
x*y - z <=(z ** 2 + 40) ** 0.5
# Out:
# True

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 5
a = a + 1
print(a)
# Out:
# 6

# %%
a = 5
a += 1
print(a)
# Out:
# 6

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
y = 4
z = 9

# %%
x > y and z > x
# Out:
# True

# %%
x + y >= z and x + z < y
# Out:
# False
