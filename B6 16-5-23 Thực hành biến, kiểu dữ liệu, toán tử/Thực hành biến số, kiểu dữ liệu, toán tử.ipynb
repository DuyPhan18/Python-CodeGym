# %% [markdown]
# # Bài 1
# ![z4350589631387_a2e36add098f0b97abf013dd8cd4a68d.jpg](attachment:z4350589631387_a2e36add098f0b97abf013dd8cd4a68d.jpg)

# %%
d_toan = 7
d_ly = 6
d_hoa = 8

# %%
AVG = (d_toan + d_ly + d_hoa) / 3
print(AVG)
print(AVG >= 8)
print(6 <= AVG <8)
print(AVG < 6)
# Out:
# 7.0
# False
# True
# False

# %% [markdown]
# # Bài 2
# ![image.png](attachment:image.png)

# %%
participation_percent = 80
course_complete_percent = 85
final_exam_mark = 8.5

print(participation_percent > 75 and course_complete_percent > 80 and final_exam_mark >= 7.5)
# Out:
# True

# %% [markdown]
# # Bài 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v_1h = 33
v_1p = 33/60
s_1h12p =v_1p*(60+12)
print(v_1p)
print(s_1h12p)
# Out:
# 0.55
# 39.6

# %% [markdown]
# # Bài 4
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dai = 16
rong = 10

s1 = dai*rong
print("diện tích s1:",s1)
dai+=4
print("chiều dài mới là:",dai)
s2= dai*rong
print("diện tích s2:", s2)
phan_tram = ((s2 - s1)*100//s1)
print("Diện tích HCN tăng:",phan_tram,"%")
# Out:
# diện tích s1: 160
# chiều dài mới là: 20
# diện tích s2: 200
# Diện tích HCN tăng: 25 %

# %% [markdown]
# # Bài 5
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v_xemay = 36
v_xedap = 12
quang_duong_AB = 48

hieu_van_toc = v_xemay - v_xedap
thoi_gian_gap_nhau = quang_duong_AB / hieu_van_toc
print(thoi_gian_gap_nhau)
# Out:
# 2.0
