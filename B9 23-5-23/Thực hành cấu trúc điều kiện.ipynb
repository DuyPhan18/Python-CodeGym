# %% [markdown]
# # NHÓM 1 - Thực hành: Cấu trúc điều kiện

# %% [markdown]
# ### Bài 1: Viết chương trình nhập vào chiều dài và chiều rộng của hình chữ nhật và cho biết đó có phải là hình vuông hay không.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
length = int(input("input length :"))
width = int(input("input width :"))
if length == width:
    print("this is square")
else:
    print("this is not square")
# Out:
# input length :10
# input width :12
# this is not square

# %% [markdown]
# ### Bài 2: Viết chương trình nhập vào 2 số a, b và in ra số lớn nhất

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
num_a = int(input("Enter number a: "))
num_b = int(input("Enter number b: "))
if num_a > num_b:
    print("a lớn hơn b")
else:
    print(" b lớn hơn a")
# Out:
# Enter number a: 232
# Enter number b: 1
# a lớn hơn b

# %% [markdown]
# ### Bài 3: Viết chương trình nhập vào 3 số a, b, c và in ra số lớn nhất

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Tạo hàm tìm số lớn nhất
def find_max(a, b, c):
    max = a
    if max < b: max = b
    if max < c: max = c
    return max
# Hàm chính
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
c = int(input("Nhập c: "))
print("Số lớn nhất trong ba số ", a, ",", b, ",", c, " là ", find_max(a, b, c))
# Out:
# Nhập a: 2
# Nhập b: 3
# Nhập c: 5
# Số lớn nhất trong ba số  2 , 3 , 5  là  5

# %%
# num_a = int(input("Enter number a: "))
# num_b = int(input("Enter number a: "))
# num_c = int(input("Enter number a: "))

# max = num_a
# if max < num_b:
#     max = num_b
#     if max < num_c:
#         max = num_c
#         print(f"số lớn nhất là: {max}")
#     else: 
#         print(f"số lớn nhất là: {max}")
# elif max < num_c:
#     max = num_c
#     print(f"số lớn nhất là: {max}")
# else:
#     print(f"số lớn nhất là: {max}")

# %% [markdown]
# ### Bài 4: Viết chương trình nhập vào số tuổi của 3 người và cho biết ai là người trẻ nhất và ai là người lớn tuổi nhất

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
human_a = int(input("input human_a :"))
human_b = int(input("input human_b :"))
human_c = int(input("input human_c :"))
if (human_a >= human_b) and (human_a >= human_c):
    print("human_a is the oldest")
    if human_b > human_c:
        print("human_c is the youngest")
    else:
        print("human_b is the youngest")
elif human_b > human_a and human_b > human_c:
    print("human_b is the oldest")
    if human_a > human_c:
        print("human_c is the youngest")
    else:
        print("human_a is the youngest")
else:
    print("human_c is the oldest")
    if human_a > human_b:
        print("human_b is the youngest")
    else:
        print("human_a is the youngest")
# Out:
# input human_a :10
# input human_b :122
# input human_c :13
# human_b is the oldest
# human_a is the youngest

# %% [markdown]
# ### Bài 5: Viết chương trình nhập vào một số bất kỳ và in ra giá trị tuyệt đối của số đó

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=int(input("Nhập a:"))
d=abs(a)
print(d,"là trị tuyệt đối của",a)
# Out:
# Nhập a:5
# 5 là trị tuyệt đối của 5

# %% [markdown]
# ### Bài 6: Học viên sẽ không đủ điều kiện thi nếu tỉ lệ có mặt nhỏ hơn 75%. Viết chương trình nhập vào tổng số buổi học của một khóa học và tổng số buổi học mà học viên tham gia. Sau đó cho biết học viên đó có đủ điều kiện thi hay không.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
condition = 75
total_num_course = int(input("Enter total number of course: "))
attend = int(input("Enter total number of course attend: "))
attendance_percent = (attend*100)//total_num_course
if attendance_percent > 75:
    print(f"Attendance percent is {attendance_percent}%. Eligible for the exam!")
else:
    print(f"Attendance percent is {attendance_percent}%. Ineligible for the exam!")
# Out:
# Enter total number of course: 30
# Enter total number of course attend: 27
# Attendance percent is 90%. Eligible for the exam!

# %% [markdown]
# ### Bài 7: Một công ty vận tải có cách tính chi phí giao hàng như sau:
# 1. 10kilogram đầu tiên: \$5/kg
# 2. Từ kilogram thứ 11 đến 20: \$7/kg
# 3. Từ kilogram thứ 20 trở lên: \$10/kg
#
# Viết chương trình nhập vào số kg cần giao(số nguyên) và in ra chi phí giao hàng tương ứng

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=int(input("nhập vào số kg cần giao:"))
if a<=10: print("Chi phí giao hàng của",a,"kg là",a*5)
elif 11<=a<=20: print("Chi phí giao hàng của",a,"kg là",10*5+(a-10)*7)
elif a>=20: print("Chi phí giao hàng của",a,"kg là",10*5+10*7+(a-20)*10)

# %% [markdown]
# ### Bài 8: Viết chương trình nhập vào số năm và cho biết năm đó là năm nhuận hay năm không nhuận.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
year = int(input("Enter a year: "))
if year % 4 == 0 and year % 100 != 0:
    print(f"{year} is leap year")
else:
    print(f"{year} is not leap year")
# Out:
# Enter a year: 2104
# 2104 is leap year

# %% [markdown]
# ### Bài 9: Viết chương trình nhập vào 1 số từ 1 đến 7 và in ra số ngày trong tuần tương ứng như sau:
#
# - 1: Sunday
# - 2: Monday
# - 3: Tuesday
# - 4: Wednesday
# - 5: Thursday
# - 6: Friday
# - 7: Saturday

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
    day = int(input("input day :"))

    if day == 1 :
        print ('day  ', day,' is  sunday')
    elif day == 2 :
        print ('day  ', day,' is  Monday')
    elif day == 3 :
        print ('day  ', day,' is  Tuesday')
    elif day == 4 :
        print ('day  ', day,' is  Wednesday')
    elif day == 5 :
        print ('day  ', day,' is  Thursday')
    elif day == 6 :
        print ('day  ', day,' is  Wednesday')
    elif day == 7 :
        print ('day  ', day,' is  Thursday') 
    else:
        print("I don't know")
# Out:
# input day :4
# day   4  is  Wednesday

# %% [markdown]
# ### Bài 10:
# Tại một cửa hàng nọ có menu như sau:
#
# 1. Gà rán giá 35k
# 2. Hamburger giá 50k
# 3. Pesi giá 10k
#
# Nhập số lượng món hàng cần mua
#
# Tính và in ra tổng giá tiền
#
# Nếu giá trị đơn hàng trên 2 triệu, giảm 10% cho khách, trên 4 triệu, giảm 15%
#
# Tính và in ra tổng giá tiền được giảm
#
# Tính và in ra tổng giá tiền khách cần trả
#
# In ra dòng chữ "Cảm ơn quý khách đã mua hàng"

# %%
"""Ví dụ:
Nhập số lượng gà rán khách mua:100
Nhập số lượng hamburger khách mua:100
Nhập số lượng pesi khách mua:15
Tổng giá tiền đơn hàng là: 8.650.000
Tổng tiền được giảm là: 1.297.500
Tổng tiền phải thanh toán: 7.352.500
Cảm ơn quý khách đã mua
"""

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
fried_chicken = 35000
hamburger = 50000
pepsi = 10000

print("-----MENU-----")
print("Fried chicken: 35 000")
print("Hamburger: 50 000")
print("Pepsi: 10 000")
print("--------------")

quantity_fc = int(input("Enter quantity of fried chicken: "))
fc_price = fried_chicken * quantity_fc
quantity_ham = int(input("Enter quantity of hamburger: "))
ham_price = hamburger * quantity_ham
quantity_ps = int(input("Enter quantity of pepsi: "))
ps_price = pepsi * quantity_ps
total_price = ( fc_price + ham_price + ps_price )
print(f"Tổng đơn hàng là : {total_price}")
if total_price > 4000000:
    discount_price = ((total_price*15)//100)
    print(f"Tổng tiền được giảm là: {discount_price}")
    total_price = total_price - discount_price
    print(f"Tổng tiền phải thanh toán là: {total_price}")
    print("Cảm ơn quý khách đã mua")
elif total_price >2000000:
    discount_price = ((total_price*10)//100)
    print(f"Tổng tiền được giảm là: {discount_price}")
    total_price = total_price - discount_price
    print(f"Tổng tiền phải thanh toán là: {total_price}")
    print("Cảm ơn quý khách đã mua")
else:
    print(f"Tổng tiền phải thanh toán là: {total_price}")
    print("Cảm ơn quý khách đã mua")
# Out:
# -----MENU-----
# Fried chicken: 35 000
# Hamburger: 50 000
# Pepsi: 10 000
# --------------
# Entter quantity of fried chicken: 57
# Entter quantity of hamburger: 35
# Entter quantity of pepsi: 15
# Tổng đơn hàng là : 3895000
# Tổng tiền được giảm là: 389500
# Tổng tiền phải thanh toán là: 3505500
# Cảm ơn quý khách đã mua

# %% [markdown]
# ### Bài 11:
#
# Nhập vào chiều cao (cm) và cân nặng (kg), tính số BMI và xét rồi xin kết quả theo dữ liệu sau:
#
# - BMI < 16: Gầy cấp độ III
# - 16 <= BMI < 17:  Gầy cấp độ II
# - 17<= BMI < 18.5: Gầy cấp độ I
# - 18.5 <= BMI < 25: Bình thường
# - 25 <= BMI < 30: Thừa cân
# - 30 <= BMI < 35 : Béo phì cấp độ I
# - 35 <= BMI < 40: Béo phì cấp độ II
# - BMI > 40: Béo phì cấp độ III

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
height = int(input("Enter your height(cm): "))
weight = int(input("Enter your weight(kg): "))
height = height/100
print(f"height(m): {height}")
BMI = round(weight/height**2,2)

if BMI < 18.5:
    if BMI < 16:
        print(f"BMI: {BMI}, Gầy cấp độ III")
    if 16 <= BMI < 17:
        print(f"BMI: {BMI}, Gầy cấp độ II")
    if 17 <= BMI < 18.5:
        print(f"BMI: {BMI}, Gầy cấp độ I")
elif BMI > 30:
    if BMI > 40:
        print(f"BMI: {BMI}, Béo phì cấp độ III")
    if 35 <= BMI < 40:
        print(f"BMI: {BMI}, Béo phì cấp độ II")
    if 30 <= BMI < 35:
        print(f"BMI: {BMI}, Béo phì cấp độ I")
elif 25 < BMI < 30:
    print(f"BMI: {BMI}, Thừa cân")
elif 18.5 <= BMI < 25:
    print(f"BMI: {BMI}, Bình thường")
# Out:
# Enter your height(cm): 175
# Enter your weight(kg): 70
# height(m): 1.75
# BMI: 22.86, Bình thường

# %% [markdown]
# ### Bài 12: Tìm ra người lớn tuổi nhất trong 4 người thông qua số tuổi nhập vào từ người dùng.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
age_p1 = int(input("Enter age of person 1: "))
age_p2 = int(input("Enter age of person 2: "))
age_p3 = int(input("Enter age of person 3: "))
age_p4 = int(input("Enter age of person 4: "))

max = age_p1
if max < age_p2:
    max = age_p2
    if max < age_p3:
        max = age_p3
        if max < age_p4:
            max = age_p4
            print(f"Người có số tuổi lớn nhất là: {max}")
        else:
            print(f"Người có số tuổi lớn nhất là: {max}")
    else: 
        print(f"Người có số tuổi lớn nhất là: {max}")
elif max < age_p3:
    max = age_p3
    if max < age_p4:
        max = age_p4
        print(f"Người có số tuổi lớn nhất là: {max}")
    else:
        print(f"Người có số tuổi lớn nhất là: {max}")
elif max < age_p4:
    max = age_p4
    print(f"Người có số tuổi lớn nhất là: {max}")
else:
    print(f"Người có số tuổi lớn nhất là: {max}")
# Out:
# Enter age of person 1: 23
# Enter age of person 2: 43
# Enter age of person 3: 55
# Enter age of person 4: 5
# Người có số tuổi lớn nhất là: 55

# %% [markdown]
# ## BONUS

# %% [markdown]
# ### Bài 13: Viết chương trình nhập vào số đo 3 cạnh của tam giác và cho biết đó là tam giác cân, tam giác đều hay tam giác vô hướng
# Ghi chú:
#  - Tam giác cân là tam giác có 2 cạnh bằng nhau
#  - Tam giác đều là tam giác có 3 cạnh bằng nhau
#  - Tam giác vô hướng là tam giác không có cạnh nào bằng nhau

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input("Nhập dộ dài cạnh a: "))
b = int(input("Nhập độ dài cạnh b: "))
c = int(input("Nhập độ dài cạnh c: "))
if a == b or a==c:
    print("Đây là tam giác cân")
elif a==b and a==c:
    print("Đây là tam giác đều")
else:
    print("Đây là tam giác vô hướng")
# Out:
# Nhập dộ dài cạnh a: 3
# Nhập độ dài cạnh b: 4
# Nhập độ dài cạnh c: 3
# Đây là tam giác cân

# %% [markdown]
# ### Bài 14: Viết chương trình nhập vào 3 số nguyên khác nhau và in ra số lớn thứ hai

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
num_a = int(input("Enter num a: "))
num_b = int(input("Enter num b: "))
num_c = int(input("Enter num c: "))

if num_a < num_b < num_c or num_c < num_b < num_a:
    print(f"mid: {num_b}")
elif num_b < num_a < num_c or num_c < num_a < num_b:
    print(f"mid: {num_a}")
else:
    print(f"mid: {num_c}")
# Out:
# Enter num a: 123124
# Enter num b: 42342
# Enter num c: 222
# mid: 42342

# %% [markdown]
# ### Bài 15: Xem đoạn code sau:
# ![image.png](attachment:image.png)
# Nếu i, j, k có các giá trị ban đầu là:
#
# a. i = 3, j = 5, k = 7
#
# b. i = 13, j = 15, k = 13
#
# Thì giá trị của i, j, k sau khi thực hiện đoạn code trên là bao nhiêu?(kiểm tra bằng cách tính nhẩm, không code lại)

# %% [markdown]
# a. i = 5, j = 5, k = 7
# b. i = 13, j = 13, k = 13

# %% [markdown]
# ### Bài 16: Viết một chương trình thực hiện phép tính đơn giản như sau:
# ```
#     Nhập số thứ nhất: 16
#     Nhập số thứ hai: 9
#     Nhập toán tử (+, -, *, /): +
#     Kết quả: 16 + 9 = 25
# ```

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
num_1 = int(input("Nhập số thứ nhất: "))
num_2 = int(input("Nhập số thứ hai: "))
operator = input("Nhập toán tử (+, -, *, /): ")

if operator == "+":
    result = num_1 + num_2 
    print(f"Kết quả: {num_1} {operator} {num_2} = {result}") 
elif operator == "-":
    result = num_1 - num_2 
    print(f"Kết quả: {num_1} {operator} {num_2} = {result}") 
elif operator == "*":
    result = num_1 * num_2 
    print(f"Kết quả: {num_1} {operator} {num_2} = {result}") 
elif operator == "/":
    result = num_1 / num_2 
    print(f"Kết quả: {num_1} {operator} {num_2} = {result}") 
else: 
    print("Không hợp lệ!")
# Out:
# Nhập số thứ nhất: 18
# Nhập số thứ hai: 3
# Nhập toán tử (+, -, *, /): *
# Kết quả: 18 * 3 = 54

# %% [markdown]
# ### Bài 17: Viết chương trình nhập vào 3 số nguyên và in ra màn hình theo thứ tự từ lớn đến bé.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num_a = int(input("Enter number a: "))
num_b = int(input("Enter number b: "))
num_c = int(input("Enter number c: "))

if num_a <= num_b <= num_c:
    print(f"{num_c}, {num_b}, {num_a}")
elif num_a <= num_c <=num_b:
    print(f"{num_b}, {num_c}, {num_a}")
elif num_b <= num_a <= num_c:
    print(f"{num_c}, {num_a}, {num_b}")
elif num_b <= num_c <= num_a:
    print(f"{num_a}, {num_c}, {num_b}")
elif num_c <= num_a <= num_b:
    print(f"{num_b}, {num_a}, {num_c}")
else:
    print(f"{num_a}, {num_b}, {num_c}")
# Out:
# Enter number a: 324
# Enter number b: 11
# Enter number c: 134
# 324, 134, 11
