# %%
"""
Warm-up 1: Cho một danh sách sản phẩm như sau:
products = {
    'SMART WATCH': 550,
    'PHONE' : 1000,
    'PLAYSTATION': 500,
    'LAPTOP' : 1550,
    'MUSIC PLAYER' : 600,
    'TABLET' : 400 
}
Viết chương trình hiển thị các sản phẩm có giá bé hơn hoặc bằng so với giá tiền mà người dùng nhập
"""

# %%
products = {
    'SMART WATCH': 550,
    'PHONE' : 1000,
    'PLAYSTATION': 500,
    'LAPTOP' : 1550,
    'MUSIC PLAYER' : 600,
    'TABLET' : 400 
}
money = int(input("Input money: "))

#lặp key trong danh sách sản phẩm
for key in products.keys():
    #nếu value tại key <= money thì in key ra
    if products[key] <= money:
        print(key,":", products[key])
# Out:
# Input money: 550
# SMART WATCH : 550
# PLAYSTATION : 500
# TABLET : 400

# %%
"""
Warm-up 2: 
"""

# %% [markdown]
# ## Bài 1: list to dict
# Cho 2 list có cùng số phần tử với nhau. Hãy tạo ra một dict từ 2 list đã cho theo format dưới đây:

# %% [markdown]
# **Input**

# %%
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]

# %% [markdown]
# **Output**

# %%
{'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %% [markdown]
# **Your code**

# %%
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]
# code below this line
#tạo dict rỗng
dic = {}
#lặp i lấy index 
for i in range(len(keys)):
    dic[keys[i]] = values[i]
print(dic)
# code above this line
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %% [markdown]
# ## Bài 2: merge dictionary
# Hãy gộp 2 dictionary sau đây thành một.

# %% [markdown]
# **Input**

# %%
dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
dict2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# %% [markdown]
# **Output**

# %%
{'Ten': 10, 'Twenty': 20, 'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# %% [markdown]
# **Your code**

# %%
dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
dict2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}
# code below this line
#dùng hàm update để ghép 2 dict
#dict1.update(dict2)
for i in dict2.keys():
    dict1[i] = dict2[i]
dict1
# code above this line
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# %% [markdown]
# ## Bài 3: where is the value?
# Hãy in ra giá trị của "history" trong dictionary dưới đây.

# %% [markdown]
# **Input**

# %%
sampleDict = { 
   "class":{ 
      "student":{ 
         "name":"Mike",
         "marks":{ 
            "physics":70,
            "history":80
         }
      }
   }
}

# %% [markdown]
# **Output**

# %%
80

# %% [markdown]
# **Your code**

# %%
sampleDict = { 
   "class":{ 
      "student":{ 
         "name":"Mike",
         "marks":{ 
            "physics":70,
            "history":80
         }
      }
   }
}
# code below this line
print(sampleDict["class"]["student"]["marks"]["history"])
# code above this line
# Out:
# 80

# %% [markdown]
# ## Bài 4: Delete set of keys from a dictionary
# Hãy xóa các key có trong set dưới đây ra khỏi dictionary.

# %% [markdown]
# **Input**

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
  
}
keysToRemove = {"name", "salary"}

# %% [markdown]
# **Output:**

# %%
{'city': 'New york', 'age': 25}

# %% [markdown]
# **Your code**

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
  
}
keysToRemove = {"name", "salary"}
# code below this line
#lặp key trong key to remove
for key in keysToRemove:
    #thực hiện xoá phần tử tại key trong sampleDict
    sampleDict.pop(key)
print(sampleDict)
# code above this line
# Out:
# {'age': 25, 'city': 'New york'}

# %% [markdown]
# ## Bài 5: Check if a value 200 exists in a dictionary
# Hãy kiểm tra xem số 200 có phải là value của dictionary dưới đây không nhé.

# %% [markdown]
# **Input**

# %%
sampleDict = {'a': 100, 'b': 200, 'c': 300}

# %% [markdown]
# **Output**

# %%
True

# %% [markdown]
# **Your code**

# %%
sampleDict = {'a': 100, 'b': 200, 'c': 300, 'd':200}
# code below this line
#lặp lấy value trong sanmpleDict
for value in sampleDict.values():
    #kiểm tra lần lượt value nếu có value = 200 thì in ra true
    if value == 200:
        print("True")
        break
# code above this line
# Out:
# True

# %% [markdown]
# ## Bài 6: rename key
# Hãy thay thế key `city` thành `location` trong dictionary dưới đây.

# %% [markdown]
# **Input**

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
}

# %% [markdown]
# **Output**

# %%
{
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "location": "New york"
}

# %% [markdown]
# **Your code**

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
}

for key in sampleDict:
    if key == "city":
        sampleDict.pop(key)
        sampleDict["location"] = key
        break
print(sampleDict)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'city'}

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
}
# code below this line
#xoá key city
v = sampleDict.pop("city")
#thêm key location
sampleDict["Location"] = v
print(sampleDict)
# code above this line
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'Location': 'New york'}

# %% [markdown]
# ## Bài 7: key of minimum value
# Hãy in ra key chứa value nhỏ nhất trong dictionary dưới đây.

# %% [markdown]
# **Input**

# %%
sampleDict = {
  'Physics': 82,
  'Math': 65,
  'history': 75
}

# %% [markdown]
# **Output**

# %%
Math

# %% [markdown]
# **Your code**

# %%
sampleDict = {
  'Physics': 82,
  'Math': 65,
  'history': 75,
    'abc':50
}
# code below this line
vals = list(sampleDict.values())
min_val = vals[0]
for i in vals:
    if min_val > i:
        min_val = i
for k, v in sampleDict.items():
    if v == min_val:
        print(k)
# code above this line
# Out:
# abc

# %%
sorted_dict = dict(sorted(sampleDict.items(), key = lambda x:x[1], reverse = False))
sorted_dict
# Out:
# {'abc': 50, 'Math': 65, 'history': 75, 'Physics': 82}

# %% [markdown]
# ## Bài 8: new salary
# Hãy tăng lương(`salary`) cho Brad từ 6500 lên 8500 trong dictionary dưới đây nhé.

# %% [markdown]
# **Input**

# %%
sampleDict = {
     'emp1': {'name': 'Jhon', 'salary': 7500},
     'emp2': {'name': 'Emma', 'salary': 8000},
     'emp3': {'name': 'Brad', 'salary': 6500}
}

# %% [markdown]
# **Output**

# %%
sampleDict = {
     'emp1': {'name': 'Jhon', 'salary': 7500},
     'emp2': {'name': 'Emma', 'salary': 8000},
     'emp3': {'name': 'Brad', 'salary': 8500}
}

# %% [markdown]
# **Your code**

# %%
sampleDict = {
     'emp1': {'name': 'Jhon', 'salary': 7500},
     'emp2': {'name': 'Emma', 'salary': 8000},
     'emp3': {'name': 'Brad', 'salary': 6500}
}
# code below this line
# sampleDict["emp3"]["salary"] = 8500
#lặp lấy key trong sampleDict
for key in sampleDict.keys():
    #Ktra nếu value của key "name" lòng bên trong của sampleDict tại key (emp1,emp2,emp3) là Brad
    if sampleDict[key]["name"] == "Brad":
        #gán giá trị mới cho key "salary" lòng bên trong của sampleDict tại key(emp3) là 8500
        sampleDict[key]["salary"] = 8500
        
print("\n".join("{}\t{}".format(k, v) for k, v in sampleDict.items()))
# code above this line
# Out:
# emp1	{'name': 'Jhon', 'salary': 7500}
# emp2	{'name': 'Emma', 'salary': 8000}
# emp3	{'name': 'Brad', 'salary': 8500}

# %%
student = {
    ('Hà Văn Hoàng', 24, 'Hà Nội') : [6, 9, 10],
    ('Trần Minh Tân', 26, 'Nghệ An') : [5, 8, 7],
    ('Cao Hoàng Yến', 20, 'Bắc Ninh') : [6, 10, 5]
}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Your code

# %%
student = {
    ('Hà Văn Hoàng', 24, 'Hà Nội') : [6, 9, 10], #7.75
    ('Trần Minh Tân', 26, 'Nghệ An') : [5, 8, 7], #6.25
    ('Cao Hoàng Yến', 20, 'Bắc Ninh') : [6, 10, 5], #6.75
  
}

#Hàm tìm điểm lớn nhất trong danh sách
def max_mark(mark):
    max_mark = mark[0]
    for j in mark:
        if max_mark < j:
            max_mark = j 
    return max_mark

#tạo danh sách điểm toán
m_math=[]
for v in student.values():
    #tìm giá trị đầu là điểm toán và thêm vào danh sách điểm toán
    for i in v:
        #gán điểm toán = v tại index = 0
        math_mark = v[0]
    m_math.append(math_mark)
print(f"Math_list: {m_math}")

#tính điểm tổng kết thêm vào danh sách điểm của từng sv
#tạo danh sách điểm tổng kết avg
avg =[]
for v in student.values():
    avg_mark = (sum(v) - v[0] + v[0] * 2 ) / (len(v)+1)
    avg.append(avg_mark)
    #Ktra xep loai sinh vien theo diem tong ket va them vao values
    if avg_mark < 5: 
        grade = "Yeu"
    elif  avg_mark < 6: 
        grade = "Trung Binh"
    elif  avg_mark < 8: 
        grade = "Kha"
    else: 
        grade = "Gioi"
        
    v.append(avg_mark)
    v.append(grade)
    
print(f"AVG:{avg}")
print("")

#gọi hàm
math = max_mark(m_math)
#tìm info sinh viên có điểm toán cao nhất
print(f"Danh sách sinh viên có điểm toán cao nhất:")
for key in student.keys():
    a = student[key]
    for m in a:     
        if a[0] == math:
            print(key[0])
            break
print("")
print(f"Danh sách sinh viên có điểm tổng kết cao nhất:")
#gọi hàm max_mark tim diem avg lon nhat
avg_m = max_mark(avg)
for key in student.keys():
    a = student[key]
    #Ktra điểm avg sv nào cao nhất in ra tên sv
    if a[len(a) - 2] == avg_m:
        print(key[0])
        break
print("")
#in ra dict
for i in student:
    print(i,":",student[i])
print("")

#Xap sep sv theo ten
sort_by_name = {}
for key in sorted(student.keys()):
    sort_by_name[key] = student[key]
sort_by_name

#Xap sep sv theo xep loai
print(f"Danh sách sinh viên xắp sếp theo xép loại:")
sort_by_grade = dict(sorted(student.items(), key=lambda x: x[1][-1]))
print(sort_by_grade)
print("")
#Xap sep sv theo thu tu giam dan diem toan
print(f"Danh sách sinh viên xắp sếp theo điểm toán:")
sort_by_math_m = dict(sorted(student.items(), key=lambda x: x[1][0], reverse = True))
sort_by_math_m
print(sort_by_math_m)
# Out:
# Math_list: [6, 5, 6]
# AVG:[7.75, 6.25, 6.75]
#
# Danh sách sinh viên có điểm toán cao nhất:
# Hà Văn Hoàng
# Cao Hoàng Yến
#
# Danh sách sinh viên có điểm tổng kết cao nhất:
# Hà Văn Hoàng
#
# ('Hà Văn Hoàng', 24, 'Hà Nội') : [6, 9, 10, 7.75, 'Kha']
# ('Trần Minh Tân', 26, 'Nghệ An') : [5, 8, 7, 6.25, 'Kha']
# ('Cao Hoàng Yến', 20, 'Bắc Ninh') : [6, 10, 5, 6.75, 'Kha']
#
# Danh sách sinh viên xắp sếp theo xép loại:
# {('Hà Văn Hoàng', 24, 'Hà Nội'): [6, 9, 10, 7.75, 'Kha'], ('Trần Minh Tân', 26, 'Nghệ An'): [5, 8, 7, 6.25, 'Kha'], ('Cao Hoàng Yến', 20, 'Bắc Ninh'): [6, 10, 5, 6.75, 'Kha']}
#
# Danh sách sinh viên xắp sếp theo điểm toán:
# {('Hà Văn Hoàng', 24, 'Hà Nội'): [6, 9, 10, 7.75, 'Kha'], ('Cao Hoàng Yến', 20, 'Bắc Ninh'): [6, 10, 5, 6.75, 'Kha'], ('Trần Minh Tân', 26, 'Nghệ An'): [5, 8, 7, 6.25, 'Kha']}
